# %%
import pandas as pd
import yaml
from datetime import datetime
from pathlib import Path
import numpy as np

# %%
df = pd.read_csv("../../../FIRE/data/gastos/ExportGastos.csv")

# %%
df
# Out:
#            Date Interest Date     Amount             Account  \
# 0    2023-06-27    2023-06-27   4.000,00  NL89BUNQ2093292122
# 1    2023-06-27    2023-07-01      -0,58  NL89BUNQ2093292122
# 2    2023-06-27    2023-07-01       0,58  NL89BUNQ2093292122
# 3    2023-06-27    2023-07-01  -2.190,31  NL89BUNQ2093292122
# 4    2023-06-28    2023-07-01   2.190,31  NL89BUNQ2093292122
# ..          ...           ...        ...                 ...
# 99   2023-07-29    2023-07-29      -3,53  NL89BUNQ2093292122
# 100  2023-07-30    2023-07-30      -9,00  NL89BUNQ2093292122
# 101  2023-07-30    2023-07-31      -5,00  NL89BUNQ2093292122
# 102  2023-07-30    2023-07-30      -6,69  NL89BUNQ2093292122
# 103  2023-07-30    2023-07-30      -4,99  NL89BUNQ2093292122
#
#            Counterparty                    Name  \
# 0      BE48967056780227            TransferWise
# 1                   NaN  GOOGLE *TEMPORARY HOLD
# 2                   NaN  GOOGLE *TEMPORARY HOLD
# 3                   NaN             WWW.IKEA.NL
# 4                   NaN             WWW.IKEA.NL
# ..                  ...                     ...
# 99                  NaN                 AH 8684
# 100                 NaN       Albert Heijn 1391
# 101  NL61INGB0389809039          Emily Heinhuis
# 102                 NaN  Jumbo Amsterdam C Huyg
# 103                 NaN       ALBERT HEIJN 1391
#
#                                            Description
# 0                             DE ARAUJO PEREIRA DANIEL
# 1    GOOGLE *TEMPORARY HOLD cc@google.com, IE 3.00 ...
# 2    Refund: GOOGLE *TEMPORARY HOLD cc@google.com, ...
# 3                            WWW.IKEA.NL AMSTERDAM, NL
# 4                           WWW.IKEA.NL AMSTERDAM, 000
# ..                                                 ...
# 99                               AH 8684 AMSTERDAM, NL
# 100                    Albert Heijn 1391 AMSTERDAM, NL
# 101                                                NaN
# 102               Jumbo Amsterdam C Huyg AMSTERDAM, NL
# 103                    ALBERT HEIJN 1391 AMSTERDAM, NL
#
# [104 rows x 7 columns]

# %%
df['Name'].unique()
# Out:
# array(['TransferWise', 'GOOGLE *TEMPORARY HOLD', 'WWW.IKEA.NL',
#        'IKEA BV via ING', 'Bever Amsterdam', 'Albert Heijn 1080',
#        'Albert Heijn 1391', 'Hart Van Zuid', "McDonald's Albert Cuyp",
#        'Greenwoods', 'ZARA HOME VAN BAERLEST', 'SIMON MEIJSSEN',
#        'Restaurant Pastis', 'EGG HOUSE F HALSSTR BV',
#        'Dille en Kamille 1029', 'Coolblue', 'AMZN MKTP NL AMAZON.NL',
#        'ALBERT HEIJN 1391', 'NLOVZE5X898WQXW5LD', 'NLOVLX5MQLQPVEQ5WG',
#        'Online Payments Foundation', 'ALBERT HEIJN 2213',
#        'Marktplaats via Online Payments Foundation', 'HEMA EV842',
#        'KPN B.V.', "Kamera Express A'dam", 'DK Het Hart van Zuid',
#        'NLOVVGJ9BWWRM6V5ZQ', 'NLOVZE5X89EVPKR5LD', 'NLOVKLJ4AL9D8495ZY',
#        'Leila', 'NLOVW7JW89K477R5VP', 'NLOVB85YY9PQVLG5VE',
#        'ALBERT HEIJN 1302', 'O&O IJZERWAREN ADAM',
#        'AMAZONRETAIL WWW.AMAZO', 'NLOV9B5GLQAXN4LJ8Y', 'ETOS 7247',
#        'CCV*R EN B VAN HILTEN', 'Jumbo Amsterdam Ferd.B',
#        'Zettle_*Coffee Distric', 'P113 Pets Place',
#        'Dille en Kamille 1031', 'Zettle_*MR. BRASA Food',
#        'Empanadas Fest Food', 'Zettle_*dambrownie com',
#        'Stichting Museumkaart', 'Pathe City',
#        'Ministerie van Justitie en Veiligheid', 'TERPS ARMY',
#        'Ekoplaza Weteringsch', 'THE BOSTON CONSULTING GROUP B.V.', 'bunq',
#        'ZARA HOME NL (1680)', 'Ku Kitchen & Bar', 'Fabel Friet',
#        'AH 8684', 'Emily Heinhuis', 'Jumbo Amsterdam C Huyg'],
#       dtype=object)

# %%
yaml_dict = yaml.safe_load(Path("../../data/config.yaml").read_text())

# %%
df["clean_name"] = df["Name"].str.lower()
df['category'] = "ERR"

# %%
for cat_name, cat_list in yaml_dict['categoria_gastos'].items():
    for store_name in cat_list:
        # print(store_name)
        df['category'] = np.where(
            df["clean_name"].str.contains(store_name.lower()),
            cat_name,
            df['category']
        )


df['category'] = np.where(
    df["Amount"] > 0,
    "entradas",
    df['category']
)

# %%
df['category'].value_counts()
# Out:
# category
# groceries       36
# house           17
# roles           16
# ERR             14
# misc            10
# transporte       8
# custos_fixos     2
# gatos            1
# Name: count, dtype: int64

# %%
df[df['category'] == "ERR"]['Name'].unique()
# Out:
# array(['TransferWise', 'GOOGLE *TEMPORARY HOLD', 'Hart Van Zuid',
#        'Greenwoods', 'Online Payments Foundation', 'DK Het Hart van Zuid',
#        'O&O IJZERWAREN ADAM', 'ETOS 7247', 'CCV*R EN B VAN HILTEN',
#        'Zettle_*MR. BRASA Food', 'THE BOSTON CONSULTING GROUP B.V.'],
#       dtype=object)

# %%
df[df['category'] == "ERR"]
# Out:
#            Date Interest Date     Amount             Account  \
# 0    2023-06-27    2023-06-27   4.000,00  NL89BUNQ2093292122
# 1    2023-06-27    2023-07-01      -0,58  NL89BUNQ2093292122
# 2    2023-06-27    2023-07-01       0,58  NL89BUNQ2093292122
# 6    2023-06-28    2023-06-28     400,00  NL89BUNQ2093292122
# 13   2023-06-30    2023-07-01    -132,07  NL89BUNQ2093292122
# 15   2023-07-01    2023-08-01     -45,00  NL89BUNQ2093292122
# 28   2023-07-04    2023-07-04      -0,01  NL89BUNQ2093292122
# 31   2023-07-05    2023-07-05      -9,35  NL89BUNQ2093292122
# 36   2023-07-06    2023-07-06     -83,86  NL89BUNQ2093292122
# 49   2023-07-11    2023-07-11      -7,40  NL89BUNQ2093292122
# 50   2023-07-11    2023-07-11      -4,40  NL89BUNQ2093292122
# 55   2023-07-13    2023-07-13     -15,38  NL89BUNQ2093292122
# 56   2023-07-13    2023-07-13      -3,75  NL89BUNQ2093292122
# 64   2023-07-16    2023-07-16      -8,00  NL89BUNQ2093292122
# 86   2023-07-24    2023-07-24  10.721,25  NL89BUNQ2093292122
# 101  2023-07-30    2023-07-31      -5,00  NL89BUNQ2093292122
#
#            Counterparty                              Name  \
# 0      BE48967056780227                      TransferWise
# 1                   NaN            GOOGLE *TEMPORARY HOLD
# 2                   NaN            GOOGLE *TEMPORARY HOLD
# 6      BE48967056780227                      TransferWise
# 13                  NaN                     Hart Van Zuid
# 15                  NaN                        Greenwoods
# 28   NL56RABO0347848516        Online Payments Foundation
# 31                  NaN                        HEMA EV842
# 36                  NaN              DK Het Hart van Zuid
# 49                  NaN               O&O IJZERWAREN ADAM
# 50                  NaN               O&O IJZERWAREN ADAM
# 55                  NaN                         ETOS 7247
# 56                  NaN             CCV*R EN B VAN HILTEN
# 64                  NaN            Zettle_*MR. BRASA Food
# 86   NL25BNPA0227693620  THE BOSTON CONSULTING GROUP B.V.
# 101  NL61INGB0389809039                    Emily Heinhuis
#
#                                            Description  \
# 0                             DE ARAUJO PEREIRA DANIEL
# 1    GOOGLE *TEMPORARY HOLD cc@google.com, IE 3.00 ...
# 2    Refund: GOOGLE *TEMPORARY HOLD cc@google.com, ...
# 6                             DE ARAUJO PEREIRA DANIEL
# 13                         Hart Van Zuid Amsterdam, NL
# 15                            Greenwoods Amsterdam, NL
# 28   trad61d4a55a3ac 0020008488870988 Online Paymen...
# 31                            HEMA EV842 AMSTERDAM, NL
# 36                  DK Het Hart van Zuid AMSTERDAM, NL
# 49                   O&O IJZERWAREN ADAM AMSTERDAM, NL
# 50                   O&O IJZERWAREN ADAM AMSTERDAM, NL
# 55                             ETOS 7247 AMSTERDAM, NL
# 56                 CCV*R EN B VAN HILTEN PURMEREND, NL
# 64                   Zettle_*MR. BRASA Food DIEMEN, NL
# 86                                         SALARY JULY
# 101                                                NaN
#
#                            clean_name category
# 0                        transferwise      ERR
# 1              google *temporary hold      ERR
# 2              google *temporary hold      ERR
# 6                        transferwise      ERR
# 13                      hart van zuid      ERR
# 15                         greenwoods      ERR
# 28         online payments foundation      ERR
# 31                         hema ev842      ERR
# 36               dk het hart van zuid      ERR
# 49                o&o ijzerwaren adam      ERR
# 50                o&o ijzerwaren adam      ERR
# 55                          etos 7247      ERR
# 56              ccv*r en b van hilten      ERR
# 64             zettle_*mr. brasa food      ERR
# 86   the boston consulting group b.v.      ERR
# 101                    emily heinhuis      ERR
