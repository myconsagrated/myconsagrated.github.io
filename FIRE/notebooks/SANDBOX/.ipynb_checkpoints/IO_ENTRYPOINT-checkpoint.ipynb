# %%
from firepy.io import read_bunq_data, read_rico_data
# Out:
# 2023-07-31 18:32:31.082 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
import pandas as pd

# %%
pd.set_option("maxcolumns", None)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.set_option("maxcolumns", None)
#
# File ~/Jardim/age3/.venv_age/lib/python3.10/site-packages/pandas/_config/config.py:261, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     260 def __call__(self, *args, **kwds) -> T:
# --> 261     return self.__func__(*args, **kwds)
#
# File ~/Jardim/age3/.venv_age/lib/python3.10/site-packages/pandas/_config/config.py:156, in _set_option(*args, **kwargs)
#     153     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     155 for k, v in zip(args[::2], args[1::2]):
# --> 156     key = _get_single_key(k, silent)
#     158     o = _get_registered_option(key)
#     159     if o and o.validator:
#
# File ~/Jardim/age3/.venv_age/lib/python3.10/site-packages/pandas/_config/config.py:121, in _get_single_key(pat, silent)
# ...

# %%
read_rico_data()
# Out:
# /home/tijolo_notebook/Jardim/FIRE/firepy/io.py:279: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux_df['CAT_ATIVO'] = "FUNDOS_INVESTIMENTO"
# /home/tijolo_notebook/Jardim/FIRE/firepy/io.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux_df['TIPO_FUNDO'] = k
# /home/tijolo_notebook/Jardim/FIRE/firepy/io.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
read_rico_data().columns
# Out:
# /home/tijolo_notebook/Jardim/FIRE/firepy/io.py:279: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux_df['CAT_ATIVO'] = "FUNDOS_INVESTIMENTO"
# /home/tijolo_notebook/Jardim/FIRE/firepy/io.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aux_df['TIPO_FUNDO'] = k
# /home/tijolo_notebook/Jardim/FIRE/firepy/io.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
